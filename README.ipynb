# %% [markdown]
# # Expect Exception
#
# Expect Exception allows you to annotate cells in your Jupyter notebook that you expect to raise exceptions.  Tracebacks from these exceptions get printed normally, but execution of the notebook does not halt with that cell.  This allows you to run all the cells in the notebook at once, and it makes testing notebooks with exception-raising cells possible.
#
# Simply importing the `expectexception` module loads the Jupyter magics.

# %%
import expectexception

# %% [markdown]
# Then, cells that raise errors can be annotated with the `%%expect_exception` magic.  The magic takes as an argument the name of the exception that is expected.  Any other exception will cause execution to halt.

# %%
# %%expect_exception ZeroDivisionError
#
# 1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-af26697ab774> in <module>()
#       1
# ----> 2 1 / 0
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# A missing argument is equivalent to `Exception`.

# %%
# %%expect_exception
#
# 1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-3-af26697ab774> in <module>()
#       1
# ----> 2 1 / 0
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# If the expected exception is not raised by the cell, the magic will raise an `ExceptionExpected` error.  This can be useful in testing, to ensure that expected errors actually occur.

# %%
# %%expect_exception ZeroDivisionError
#
# 1 / 2
# Out:
# 0
# ---------------------------------------------------------------------------
# ExceptionExpected                         Traceback (most recent call last)
# <ipython-input-4-c18d43525014> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'expect_exception', u'ZeroDivisionError', u'\n1 / 2')
#
# /home/rschroll/miniconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2118             magic_arg_s = self.var_expand(line, stack_depth)
#    2119             with self.builtin_trap:
# -> 2120                 result = fn(magic_arg_s, cell)
#    2121             return result
#    2122
#
# <decorator-gen-124> in expect_exception(self, line, cell)
#
# /home/rschroll/miniconda2/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/rschroll/expectexception/expectexception/excpectexceptionmagic.pyc in expect_exception(self, line, cell)
#      19     @cell_magic
#      20     def expect_exception(self, line, cell):
# ---> 21         self.run_cell(line, cell, True)
#      22
#      23     @cell_magic
#
# /home/rschroll/expectexception/expectexception/excpectexceptionmagic.pyc in run_cell(self, line, cell, exception_required)
#      41             result = self.shell.run_cell(cell)
#      42             if exception_required and not result.error_in_exec:
# ---> 43                 raise ExceptionExpected("This cell did not raise the expected %s." % line)
#      44         finally:
#      45             self.shell.CustomTB = old_CustomTB
#
# ExceptionExpected: This cell did not raise the expected ZeroDivisionError.

# %% [markdown]
# In case this behavior is not desired, the `%%ignore_exception` magic behaves similarly but does not raise `ExceptionExpected`.
